# %%
x = 7 
y = 6

print("x + y=", x+y)
print("x - y=", x-y)
print("x * y=", x*y)
print("x / y=", x/y)
print("x // y=", x//y)
print("x % y=", x%y)
print("x ** y=", x**y)
# Out:
# x + y= 13
# x - y= 1
# x * y= 42
# x / y= 1.1666666666666667
# x // y= 1
# x % y= 1
# x ** y= 117649
